# %%
import pandas

# %%
data = pandas.read_csv('titanic.csv', index_col='PassengerId')

# %%
data[data["Sex"]=="male"].count()
# Out:
# Survived    577
# Pclass      577
# Name        577
# Sex         577
# Age         453
# SibSp       577
# Parch       577
# Ticket      577
# Fare        577
# Cabin       107
# Embarked    577
# dtype: int64

# %%
data["Sex"].value_counts()
# Out:
# male      577
# female    314
# Name: Sex, dtype: int64

# %%
data["Survived"].value_counts()
# Out:
# 0    549
# 1    342
# Name: Survived, dtype: int64

# %%
342./(342.+549.)
# Out:
# 0.3838383838383838

# %%
data["Pclass"].value_counts()
# Out:
# 3    491
# 1    216
# 2    184
# Name: Pclass, dtype: int64

# %%
216./(216.+184.+491.)
# Out:
# 0.24242424242424243

# %%
data["Age"].mean()
# Out:
# 29.69911764705882

# %%
data["Age"].median()
# Out:
# 28.0

# %%
data.corr()
# Out:
#           Survived    Pclass       Age     SibSp     Parch      Fare
# Survived  1.000000 -0.338481 -0.077221 -0.035322  0.081629  0.257307
# Pclass   -0.338481  1.000000 -0.369226  0.083081  0.018443 -0.549500
# Age      -0.077221 -0.369226  1.000000 -0.308247 -0.189119  0.096067
# SibSp    -0.035322  0.083081 -0.308247  1.000000  0.414838  0.159651
# Parch     0.081629  0.018443 -0.189119  0.414838  1.000000  0.216225
# Fare      0.257307 -0.549500  0.096067  0.159651  0.216225  1.000000

# %%
data["Name1"]=data["Name"].str.replace('Miss. ', '_')

# %%
data["Name1"]=data["Name1"].str.replace('(', '_')

# %%
data["Name1"]=data["Name1"].str.split('_').str.get(1)

# %%
data["Name1"]=data["Name1"].str.replace(')', '')

# %%
data["Name1"]=data["Name1"].str.split(' ').str.get(0)

# %%
data["Name1"].value_counts()[0:3]
# Out:
# Anna         15
# Mary         14
# Elizabeth    11
# Name: Name1, dtype: int64

# %%
data
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# 6                   0       3
# 7                   0       1
# 8                   0       3
# 9                   1       3
# 10                  1       2
# 11                  1       3
# 12                  1       1
# 13                  0       3
# 14                  0       3
# 15                  0       3
# 16                  1       2
# 17                  0       3
# 18                  1       2
# 19                  0       3
# 20                  1       3
# 21                  0       2
# 22                  1       2
# 23                  1       3
# 24                  1       1
# 25                  0       3
# 26                  1       3
# 27                  0       3
# 28                  0       1
# 29                  1       3
# ...
